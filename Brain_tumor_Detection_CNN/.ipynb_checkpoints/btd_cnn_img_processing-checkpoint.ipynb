# %%
import tensorflow as tf
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152xs
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # -1  to USE CPU
from keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense,Dropout
from keras.models import Model, load_model
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
import time
from os import listdir

get_ipython().magic(u'matplotlib inline')
# Out:
# /var/folders/90/q467pqns6cxc4dmbvlrlxbqm0000gn/T/ipykernel_1178/2964376139.py:18: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic(u'matplotlib inline')

# %%
def crop_brain_contour(image, plot=False):

    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Threshold the image, then perform a series of erosions +
    # dilations to remove any small regions of noise
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)

    # Find the extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])

    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]

    if plot:
        plt.figure()

        plt.subplot(1, 2, 1)
        plt.imshow(image)

        plt.tick_params(axis='both', which='both',
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()
    return new_image

# %%
ex_img = cv2.imread('yes/Y1.jpg')
ex_new_img = crop_brain_contour(ex_img, True)

# %%
def load_data(dir_list, image_size):
    """
    Read images, resize and normalize them. 
    Arguments:
        dir_list: list of strings representing file directories.
    Returns:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    """
    # load all images in a directory
    X = []
    y = []
    image_width, image_height = image_size
    for directory in dir_list:
        for filename in listdir(directory):
            print(filename)
            print(directory)
            # load the image
            image = cv2.imread(directory + '/' + filename)
            # print(image)
            # crop the brain and ignore the unnecessary rest part of the image
            image = crop_brain_contour(image, plot=False)
            # resize image
            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            # normalize values
            image = image / 255.
            # convert image to numpy array and append it to X
            X.append(image)
            # append a value of 1 to the target array if the image
            # is in the folder named 'yes', otherwise append 0.
            if directory[-3:] == 'yes':
                y.append([1])
            else:
                y.append([0])
    X = np.array(X)
    y = np.array(y)
    # Shuffle the data
    X, y = shuffle(X, y)
    print('Number of examples is:{}'.format(len(X)))
    return X,y

# %%
augmented_path = 'augmented_data/'
# augmented data (yes and no) contains both the original and the new generated examples
augmented_yes = augmented_path + 'yes'
augmented_no = augmented_path + 'no'
IMG_WIDTH, IMG_HEIGHT = (240, 240)
X, y = load_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# aug_Y100_0_4855.jpg
# augmented_data/yes
# aug_Y254_0_4212.jpg
# augmented_data/yes
# aug_Y37_0_9694.jpg
# augmented_data/yes
# aug_Y243_0_9105.jpg
# augmented_data/yes
# aug_Y106_0_2432.jpg
# augmented_data/yes
# aug_Y154_0_1160.jpg
# augmented_data/yes
# aug_Y82_0_3407.jpg
# augmented_data/yes
# aug_Y117_0_9217.jpg
# augmented_data/yes
# aug_Y159_0_2278.jpg
# augmented_data/yes
# aug_Y256_0_9393.jpg
# augmented_data/yes
# aug_Y35_0_5351.jpg
# augmented_data/yes
# aug_Y24_0_7550.jpg
# augmented_data/yes
# aug_Y62_0_7861.jpg
# augmented_data/yes
# aug_Y36_0_3276.jpg
# augmented_data/yes
# aug_Y2_0_9038.jpg
# augmented_data/yes
# aug_Y15_0_537.jpg
# augmented_data/yes
# aug_Y161_0_4244.jpg
# augmented_data/yes
# aug_Y105_0_1041.jpg
# augmented_data/yes
# aug_Y7_0_1893.jpg
# augmented_data/yes
# aug_Y31_0_2292.jpg
# augmented_data/yes
# aug_Y55_0_3597.jpg
# augmented_data/yes
# aug_Y42_0_5931.jpg
# augmented_data/yes
# aug_Y1_0_5234.jpg
# augmented_data/yes
# aug_Y113_0_9120.jpg
# augmented_data/yes
# aug_Y70_0_5465.jpg
# augmented_data/yes
# aug_Y10_0_5995.jpg
# augmented_data/yes
# aug_Y82_0_6609.jpg
# augmented_data/yes
# aug_Y55_0_2892.jpg
# augmented_data/yes
# aug_Y154_0_2045.jpg
# augmented_data/yes
# aug_Y159_0_9715.jpg
# augmented_data/yes
# aug_Y256_0_5436.jpg
# augmented_data/yes
# aug_Y38_0_4931.jpg
# augmented_data/yes
# aug_Y69_0_685.jpg
# augmented_data/yes
# aug_Y75_0_5299.jpg
# augmented_data/yes
# aug_Y14_0_5526.jpg
# augmented_data/yes
# aug_Y7_0_5149.jpg
# augmented_data/yes
# aug_Y74_0_239.jpg
# augmented_data/yes
# aug_Y193_0_2385.jpg
# augmented_data/yes
# aug_Y61_0_5856.jpg
# augmented_data/yes
# aug_Y89_0_3209.jpg
# augmented_data/yes
# aug_Y78_0_5310.jpg
# augmented_data/yes
# aug_Y20_0_6544.jpg
# augmented_data/yes
# aug_Y13_0_1281.jpg
# augmented_data/yes
# aug_Y155_0_2160.jpg
# augmented_data/yes
# aug_Y18_0_9819.jpg
# augmented_data/yes
# aug_Y66_0_3925.jpg
# augmented_data/yes
# aug_Y10_0_8081.jpg
# augmented_data/yes
# aug_Y1_0_4329.jpg
# augmented_data/yes
# aug_Y243_0_2131.jpg
# augmented_data/yes
# aug_Y180_0_4636.jpg
# augmented_data/yes
# aug_Y45_0_2365.jpg
# augmented_data/yes
# aug_Y22_0_197.jpg
# augmented_data/yes
# aug_Y259_0_7339.jpg
# augmented_data/yes
# aug_Y97_0_5560.jpg
# augmented_data/yes
# aug_Y162_0_6083.jpg
# augmented_data/yes
# aug_Y103_0_8711.jpg
# augmented_data/yes
# aug_Y250_0_9587.jpg
# augmented_data/yes
# aug_Y71_0_6870.jpg
# augmented_data/yes
# aug_Y249_0_9597.jpg
# augmented_data/yes
# aug_Y169_0_6289.jpg
# augmented_data/yes
# aug_Y96_0_9530.jpg
# augmented_data/yes
# aug_Y252_0_4412.jpg
# augmented_data/yes
# aug_30 no_0_1833.jpg
# augmented_data/no
# aug_29 no_0_8326.jpg
# augmented_data/no
# aug_43 no_0_1606.jpg
# augmented_data/no
# aug_41 no_0_6374.jpg
# augmented_data/no
# aug_20 no_0_9660.jpg
# augmented_data/no
# aug_14 no_0_3299.jpg
# augmented_data/no
# aug_40 no_0_622.jpg
# augmented_data/no
# aug_33 no_0_8147.jpg
# augmented_data/no
# aug_38 no_0_7180.jpg
# augmented_data/no
# aug_No12_0_7028.jpg
# augmented_data/no
# aug_N5_0_6857.jpg
# augmented_data/no
# aug_no 91._0_1255.jpg
# augmented_data/no
# aug_N16_0_7462.jpg
# augmented_data/no
# aug_No11_0_1047.jpg
# augmented_data/no
# aug_14 no_0_3845.jpg
# augmented_data/no
# aug_no 2_0_7230.jpg
# augmented_data/no
# aug_No12_0_6524.jpg
# augmented_data/no
# aug_no_0_8378.jpg
# augmented_data/no
# aug_22 no_0_4788.jpg
# augmented_data/no
# aug_31 no_0_9326.jpg
# augmented_data/no
# aug_6 no_0_2486.jpg
# augmented_data/no
# aug_11 no_0_9220.jpg
# augmented_data/no
# aug_no 9_0_9758.jpg
# augmented_data/no
# aug_No15_0_4369.jpg
# augmented_data/no
# aug_25 no_0_8766.jpg
# augmented_data/no
# aug_4 no_0_4572.jpg
# augmented_data/no
# aug_N2_0_3154.jpg
# augmented_data/no
# aug_13 no_0_7944.jpg
# augmented_data/no
# aug_N16_0_9894.jpg
# augmented_data/no
# aug_N17_0_9218.jpg
# augmented_data/no
# aug_1 no._0_1187.jpg
# augmented_data/no
# aug_47 no_0_7539.jpg
# augmented_data/no
# aug_No14_0_4271.jpg
# augmented_data/no
# aug_39 no_0_2815.jpg
# augmented_data/no
# aug_no 3_0_9890.jpg
# augmented_data/no
# aug_no 96_0_3023.jpg
# augmented_data/no
# aug_No15_0_5513.jpg
# augmented_data/no
# aug_N19_0_2591.jpg
# augmented_data/no
# aug_no 89_0_6222.jpg
# augmented_data/no
# aug_18 no_0_1541.jpg
# augmented_data/no
# aug_44no_0_8854.jpg
# augmented_data/no
# aug_43 no_0_2656.jpg
# augmented_data/no
# aug_41 no_0_5324.jpg
# augmented_data/no
# aug_2 no._0_9630.jpg
# augmented_data/no
# aug_no 9_0_5566.jpg
# augmented_data/no
# aug_23 no_0_6543.jpg
# augmented_data/no
# aug_No16_0_2676.jpg
# augmented_data/no
# aug_9 no_0_3120.jpg
# augmented_data/no
# aug_30 no_0_4779.jpg
# augmented_data/no
# aug_11 no_0_5209.jpg
# augmented_data/no
# aug_45 no_0_6770.jpg
# augmented_data/no
# aug_5 no_0_8568.jpg
# augmented_data/no
# aug_No19_0_5391.jpg
# augmented_data/no
# aug_N5_0_2601.jpg
# augmented_data/no
# aug_19 no_0_4796.jpg
# augmented_data/no
# aug_No22_0_4590.jpg
# augmented_data/no
# aug_no 91._0_5422.jpg
# augmented_data/no
# aug_37 no_0_2520.jpg
# augmented_data/no
# aug_N1_0_2865.jpg
# augmented_data/no
# aug_38 no_0_8924.jpg
# augmented_data/no
# aug_35 no_0_7645.jpg
# augmented_data/no
# aug_No20_0_8255.jpg
# augmented_data/no
# aug_N6_0_3936.jpg
# augmented_data/no
# aug_35 no_0_2073.jpg
# augmented_data/no
# aug_No15_0_3570.jpg
# augmented_data/no
# aug_36 no_0_1741.jpg
# augmented_data/no
# aug_49 no_0_7617.jpg
# augmented_data/no
# aug_11 no_0_4129.jpg
# augmented_data/no
# aug_No15_0_6434.jpg
# augmented_data/no
# aug_28 no_0_9753.jpg
# augmented_data/no
# aug_no 95_0_9674.jpg
# augmented_data/no
# aug_no 5._0_3165.jpg
# augmented_data/no
# aug_No21_0_5655.jpg
# augmented_data/no
# aug_N26_0_7980.jpg
# augmented_data/no
# aug_no 96_0_2539.jpg
# augmented_data/no
# aug_N2_0_184.jpg
# augmented_data/no
# aug_No12_0_5628.jpg
# augmented_data/no
# aug_26 no_0_3754.jpg
# augmented_data/no
# aug_no 2_0_51.jpg
# augmented_data/no
# aug_41 no_0_9468.jpg
# augmented_data/no
# aug_no 96_0_9256.jpg
# augmented_data/no
# aug_7 no_0_998.jpg
# augmented_data/no
# aug_No14_0_1684.jpg
# augmented_data/no
# aug_28 no_0_119.jpg
# augmented_data/no
# aug_2 no._0_5418.jpg
# augmented_data/no
# aug_no 8_0_8005.jpg
# augmented_data/no
# aug_No22_0_7105.jpg
# augmented_data/no
# aug_no 91._0_1928.jpg
# augmented_data/no
# aug_N19_0_8518.jpg
# augmented_data/no
# aug_No13_0_3208.jpg
# augmented_data/no
# aug_no 1_0_6877.jpg
# augmented_data/no
# aug_No12_0_5205.jpg
# augmented_data/no
# aug_4 no_0_1409.jpg
# augmented_data/no
# aug_no 95_0_9265.jpg
# augmented_data/no
# aug_no 8_0_711.jpg
# augmented_data/no
# aug_33 no_0_8964.jpg
# augmented_data/no
# aug_no 923_0_5273.jpg
# augmented_data/no
# aug_33 no_0_8757.jpg
# augmented_data/no
# aug_38 no_0_9965.jpg
# augmented_data/no
# aug_6 no_0_9704.jpg
# augmented_data/no
# aug_18 no_0_4348.jpg
# augmented_data/no
# aug_29 no_0_902.jpg
# augmented_data/no
# aug_no 89_0_2872.jpg
# augmented_data/no
# aug_N16_0_6811.jpg
# augmented_data/no
# aug_no 90_0_8624.jpg
# augmented_data/no
# aug_6 no_0_5937.jpg
# augmented_data/no
# aug_29 no_0_1670.jpg
# augmented_data/no
# aug_44no_0_3719.jpg
# augmented_data/no
# aug_38 no_0_5959.jpg
# augmented_data/no
# aug_31 no_0_8364.jpg
# augmented_data/no
# aug_21 no_0_74.jpg
# augmented_data/no
# aug_no 98_0_503.jpg
# augmented_data/no
# aug_32 no_0_3208.jpg
# augmented_data/no
# aug_N5_0_7949.jpg
# augmented_data/no
# aug_37 no_0_977.jpg
# augmented_data/no
# aug_N5_0_7752.jpg
# augmented_data/no
# aug_no 923_0_7048.jpg
# augmented_data/no
# aug_N22_0_490.jpg
# augmented_data/no
# aug_no 92_0_9612.jpg
# augmented_data/no
# aug_no 5._0_2726.jpg
# augmented_data/no
# aug_23 no_0_2252.jpg
# augmented_data/no
# aug_39 no_0_1076.jpg
# augmented_data/no
# aug_N16_0_9930.jpg
# augmented_data/no
# aug_13 no_0_6526.jpg
# augmented_data/no
# aug_N21_0_885.jpg
# augmented_data/no
# aug_13 no_0_1261.jpg
# augmented_data/no
# aug_21 no_0_5278.jpg
# augmented_data/no
# aug_26 no_0_8162.jpg
# augmented_data/no
# aug_49 no_0_4643.jpg
# augmented_data/no
# aug_36 no_0_141.jpg
# augmented_data/no
# aug_5 no_0_2240.jpg
# augmented_data/no
# aug_no 5._0_9263.jpg
# augmented_data/no
# aug_17 no_0_9827.jpg
# augmented_data/no
# aug_21 no_0_3769.jpg
# augmented_data/no
# aug_N16_0_9461.jpg
# augmented_data/no
# aug_no 90_0_4185.jpg
# augmented_data/no
# aug_10 no_0_415.jpg
# augmented_data/no
# aug_no 100_0_277.jpg
# augmented_data/no
# aug_23 no_0_2871.jpg
# augmented_data/no
# aug_17 no_0_3463.jpg
# augmented_data/no
# aug_26 no_0_5268.jpg
# augmented_data/no
# aug_N2_0_5536.jpg
# augmented_data/no
# aug_N5_0_293.jpg
# augmented_data/no
# aug_No21_0_3625.jpg
# augmented_data/no
# aug_4 no_0_8367.jpg
# augmented_data/no
# aug_27 no_0_7667.jpg
# augmented_data/no
# aug_50 no_0_6146.jpg
# augmented_data/no
# aug_6 no_0_4797.jpg
# augmented_data/no
# aug_12 no_0_7964.jpg
# augmented_data/no
# aug_13 no_0_3271.jpg
# augmented_data/no
# aug_45 no_0_5337.jpg
# augmented_data/no
# aug_N17_0_8841.jpg
# augmented_data/no
# aug_49 no_0_9038.jpg
# augmented_data/no
# aug_33 no_0_8587.jpg
# augmented_data/no
# aug_15 no_0_2788.jpg
# augmented_data/no
# aug_27 no_0_6550.jpg
# augmented_data/no
# aug_6 no_0_5852.jpg
# augmented_data/no
# aug_N21_0_3830.jpg
# augmented_data/no
# aug_46 no_0_3794.jpg
# augmented_data/no
# aug_12 no_0_547.jpg
# augmented_data/no
# aug_No18_0_589.jpg
# augmented_data/no
# aug_25 no_0_3423.jpg
# augmented_data/no
# aug_36 no_0_5866.jpg
# augmented_data/no
# aug_no 91._0_6449.jpg
# augmented_data/no
# aug_29 no_0_3704.jpg
# augmented_data/no
# aug_no 95_0_9658.jpg
# augmented_data/no
# aug_50 no_0_818.jpg
# augmented_data/no
# aug_No14_0_6064.jpg
# ...
# aug_47 no_0_2987.jpg
# augmented_data/no
# aug_33 no_0_7976.jpg
# augmented_data/no
# aug_20 no_0_3456.jpg
# augmented_data/no
# aug_13 no_0_3357.jpg
# augmented_data/no
# aug_no 6_0_349.jpg
# augmented_data/no
# aug_42 no_0_6330.jpg
# augmented_data/no
# aug_N26_0_3597.jpg
# augmented_data/no
# aug_no 3_0_2629.jpg
# augmented_data/no
# aug_N1_0_4715.jpg
# augmented_data/no
# aug_no 99_0_1167.jpg
# augmented_data/no
# aug_11 no_0_904.jpg
# augmented_data/no
# aug_15 no_0_4803.jpg
# augmented_data/no
# aug_no 95_0_5144.jpg
# augmented_data/no
# aug_47 no_0_7551.jpg
# augmented_data/no
# aug_N6_0_551.jpg
# augmented_data/no
# aug_no 92_0_1184.jpg
# augmented_data/no
# aug_No16_0_2965.jpg
# augmented_data/no
# aug_5 no_0_1646.jpg
# augmented_data/no
# aug_23 no_0_5432.jpg
# augmented_data/no
# aug_No17_0_3578.jpg
# augmented_data/no
# aug_no 96_0_3261.jpg
# augmented_data/no
# aug_no 90_0_4303.jpg
# augmented_data/no
# aug_No14_0_4999.jpg
# augmented_data/no
# aug_N6_0_8982.jpg
# augmented_data/no
# aug_No15_0_8249.jpg
# augmented_data/no
# aug_no 6_0_3296.jpg
# augmented_data/no
# aug_no_0_8106.jpg
# augmented_data/no
# aug_N20_0_5488.jpg
# augmented_data/no
# aug_N3_0_9911.jpg
# augmented_data/no
# aug_no 4_0_5726.jpg
# augmented_data/no
# aug_42 no_0_4650.jpg
# augmented_data/no
# aug_N3_0_7055.jpg
# augmented_data/no
# aug_35 no_0_7766.jpg
# augmented_data/no
# aug_49 no_0_9094.jpg
# augmented_data/no
# aug_No20_0_453.jpg
# augmented_data/no
# aug_7 no_0_6453.jpg
# augmented_data/no
# aug_no 8_0_3476.jpg
# augmented_data/no
# aug_6 no_0_4289.jpg
# augmented_data/no
# aug_No15_0_297.jpg
# augmented_data/no
# aug_17 no_0_2049.jpg
# augmented_data/no
# aug_no 7._0_627.jpg
# augmented_data/no
# aug_9 no_0_8381.jpg
# augmented_data/no
# aug_33 no_0_6062.jpg
# augmented_data/no
# aug_45 no_0_6484.jpg
# augmented_data/no
# aug_50 no_0_3508.jpg
# augmented_data/no
# aug_no 100_0_1945.jpg
# augmented_data/no
# aug_32 no_0_1893.jpg
# augmented_data/no
# aug_no 96_0_990.jpg
# augmented_data/no
# aug_18 no_0_6327.jpg
# augmented_data/no
# aug_34 no_0_5590.jpg
# augmented_data/no
# aug_No17_0_2511.jpg
# augmented_data/no
# aug_no 5._0_3640.jpg
# augmented_data/no
# aug_37 no_0_5768.jpg
# augmented_data/no
# aug_35 no_0_7835.jpg
# augmented_data/no
# aug_No15_0_863.jpg
# augmented_data/no
# aug_no_0_4648.jpg
# augmented_data/no
# aug_26 no_0_9004.jpg
# augmented_data/no
# aug_12 no_0_1201.jpg
# augmented_data/no
# aug_no 7._0_7995.jpg
# augmented_data/no
# aug_no 7._0_8330.jpg
# augmented_data/no
# aug_no 99_0_7113.jpg
# augmented_data/no
# aug_No19_0_4974.jpg
# augmented_data/no
# aug_42 no_0_6651.jpg
# augmented_data/no
# aug_9 no_0_7303.jpg
# augmented_data/no
# aug_no 9_0_720.jpg
# augmented_data/no
# aug_no 90_0_1336.jpg
# augmented_data/no
# aug_N20_0_6783.jpg
# augmented_data/no
# aug_37 no_0_3321.jpg
# augmented_data/no
# aug_N26_0_9732.jpg
# augmented_data/no
# aug_10 no_0_2713.jpg
# augmented_data/no
# aug_No21_0_5606.jpg
# augmented_data/no
# aug_No22_0_5344.jpg
# augmented_data/no
# aug_47 no_0_9431.jpg
# augmented_data/no
# aug_N17_0_4396.jpg
# augmented_data/no
# aug_no 3_0_1319.jpg
# augmented_data/no
# aug_40 no_0_3911.jpg
# augmented_data/no
# aug_No21_0_6482.jpg
# augmented_data/no
# aug_11 no_0_4422.jpg
# augmented_data/no
# aug_30 no_0_2952.jpg
# augmented_data/no
# aug_37 no_0_5142.jpg
# augmented_data/no
# aug_7 no_0_4297.jpg
# augmented_data/no
# aug_N17_0_2644.jpg
# augmented_data/no
# aug_46 no_0_4047.jpg
# augmented_data/no
# aug_18 no_0_8520.jpg
# augmented_data/no
# aug_No13_0_6849.jpg
# augmented_data/no
# aug_12 no_0_8816.jpg
# augmented_data/no
# aug_39 no_0_6388.jpg
# augmented_data/no
# aug_no 1_0_51.jpg
# augmented_data/no
# aug_33 no_0_9396.jpg
# augmented_data/no
# aug_no 89_0_4882.jpg
# augmented_data/no
# aug_no 2_0_5675.jpg
# augmented_data/no
# aug_19 no_0_798.jpg
# augmented_data/no
# aug_48 no._0_2402.jpg
# augmented_data/no
# aug_No19_0_6780.jpg
# augmented_data/no
# aug_No16_0_3128.jpg
# augmented_data/no
# aug_No14_0_352.jpg
# augmented_data/no
# aug_N15_0_6092.jpg
# augmented_data/no
# aug_24 no_0_3335.jpg
# augmented_data/no
# aug_N21_0_9387.jpg
# augmented_data/no
# aug_no 89_0_3487.jpg
# augmented_data/no
# aug_46 no_0_106.jpg
# augmented_data/no
# aug_No20_0_6606.jpg
# augmented_data/no
# aug_N2_0_5039.jpg
# augmented_data/no
# aug_14 no_0_9478.jpg
# augmented_data/no
# aug_No16_0_1267.jpg
# augmented_data/no
# aug_3 no_0_8917.jpg
# augmented_data/no
# aug_No17_0_5469.jpg
# augmented_data/no
# aug_No18_0_5232.jpg
# augmented_data/no
# aug_29 no_0_8820.jpg
# augmented_data/no
# aug_30 no_0_3278.jpg
# augmented_data/no
# aug_39 no_0_9680.jpg
# augmented_data/no
# aug_no 89_0_8459.jpg
# augmented_data/no
# aug_23 no_0_5026.jpg
# augmented_data/no
# aug_N3_0_6992.jpg
# augmented_data/no
# aug_12 no_0_5260.jpg
# augmented_data/no
# aug_No17_0_9870.jpg
# augmented_data/no
# aug_N16_0_9783.jpg
# augmented_data/no
# aug_15 no_0_2133.jpg
# augmented_data/no
# aug_N6_0_7257.jpg
# augmented_data/no
# aug_no 96_0_9172.jpg
# augmented_data/no
# aug_29 no_0_3578.jpg
# augmented_data/no
# aug_6 no_0_6712.jpg
# augmented_data/no
# aug_N3_0_7130.jpg
# augmented_data/no
# aug_21 no_0_8509.jpg
# augmented_data/no
# aug_no 92_0_3436.jpg
# augmented_data/no
# aug_14 no_0_9730.jpg
# augmented_data/no
# aug_38 no_0_8784.jpg
# augmented_data/no
# aug_48 no._0_1082.jpg
# augmented_data/no
# aug_N22_0_7577.jpg
# augmented_data/no
# aug_no 95_0_70.jpg
# augmented_data/no
# aug_19 no_0_7959.jpg
# augmented_data/no
# aug_34 no_0_7394.jpg
# augmented_data/no
# aug_35 no_0_4136.jpg
# augmented_data/no
# aug_40 no_0_3053.jpg
# augmented_data/no
# aug_no 95_0_2765.jpg
# augmented_data/no
# aug_No21_0_5605.jpg
# augmented_data/no
# aug_41 no_0_2380.jpg
# augmented_data/no
# aug_no 923_0_3096.jpg
# augmented_data/no
# aug_19 no_0_3530.jpg
# augmented_data/no
# aug_14 no_0_7292.jpg
# augmented_data/no
# aug_47 no_0_4894.jpg
# augmented_data/no
# aug_N19_0_2312.jpg
# augmented_data/no
# aug_N11_0_9094.jpg
# augmented_data/no
# aug_no 94_0_9310.jpg
# augmented_data/no
# aug_1 no._0_1102.jpg
# augmented_data/no
# aug_2 no._0_2680.jpg
# augmented_data/no
# aug_no 6_0_6128.jpg
# augmented_data/no
# aug_no 8_0_9809.jpg
# augmented_data/no
# aug_17 no_0_7693.jpg
# augmented_data/no
# aug_No18_0_250.jpg
# augmented_data/no
# aug_24 no_0_6273.jpg
# augmented_data/no
# aug_13 no_0_689.jpg
# augmented_data/no
# aug_25 no_0_6282.jpg
# augmented_data/no
# aug_11 no_0_4555.jpg
# augmented_data/no
# aug_N22_0_6537.jpg
# augmented_data/no
# aug_24 no_0_4869.jpg
# augmented_data/no
# aug_no 95_0_1654.jpg
# augmented_data/no
# aug_20 no_0_479.jpg
# augmented_data/no
# aug_48 no._0_4065.jpg
# augmented_data/no
# aug_No21_0_972.jpg
# augmented_data/no
# aug_N2_0_1922.jpg
# augmented_data/no
# aug_N15_0_4679.jpg
# augmented_data/no
# aug_30 no_0_476.jpg
# augmented_data/no
# aug_3 no_0_3302.jpg
# augmented_data/no
# aug_17 no_0_4199.jpg
# augmented_data/no
# aug_1 no._0_7980.jpg
# augmented_data/no
# aug_17 no_0_9481.jpg
# augmented_data/no
# aug_No21_0_6053.jpg
# augmented_data/no
# aug_no 4_0_3153.jpg
# augmented_data/no
# aug_no 97_0_2712.jpg
# augmented_data/no
# aug_34 no_0_2428.jpg
# augmented_data/no
# aug_24 no_0_9627.jpg
# augmented_data/no
# aug_No15_0_3680.jpg
# augmented_data/no
# aug_N19_0_2313.jpg
# augmented_data/no
# aug_48 no._0_3333.jpg
# augmented_data/no
# aug_5 no_0_3136.jpg
# augmented_data/no
# aug_no 4_0_2305.jpg
# augmented_data/no
# aug_N22_0_629.jpg
# augmented_data/no
# aug_39 no_0_8589.jpg
# augmented_data/no
# aug_no_0_2001.jpg
# augmented_data/no
# aug_N6_0_2853.jpg
# augmented_data/no
# aug_N20_0_3404.jpg
# augmented_data/no
# aug_No22_0_7592.jpg
# augmented_data/no
# aug_no 98_0_2149.jpg
# augmented_data/no
# aug_22 no_0_8282.jpg
# augmented_data/no
# aug_22 no_0_2977.jpg
# augmented_data/no
# aug_6 no_0_3443.jpg
# augmented_data/no
# aug_21 no_0_696.jpg
# augmented_data/no
# aug_no 5._0_3336.jpg
# augmented_data/no
# aug_33 no_0_1455.jpg
# augmented_data/no
# aug_12 no_0_7676.jpg
# augmented_data/no
# aug_N11_0_2414.jpg
# augmented_data/no
# aug_no 7._0_1361.jpg
# augmented_data/no
# aug_no 92_0_1523.jpg
# augmented_data/no
# aug_N5_0_7003.jpg
# augmented_data/no
# aug_21 no_0_815.jpg
# augmented_data/no
# aug_13 no_0_7637.jpg
# augmented_data/no
# aug_no 10_0_310.jpg
# augmented_data/no
# aug_no 100_0_6285.jpg
# augmented_data/no
# aug_41 no_0_3577.jpg
# augmented_data/no
# aug_no 2_0_7601.jpg
# augmented_data/no
# aug_15 no_0_5610.jpg
# augmented_data/no
# aug_No20_0_1723.jpg
# augmented_data/no
# aug_no 92_0_1053.jpg
# augmented_data/no
# aug_No18_0_1018.jpg
# augmented_data/no
# aug_10 no_0_383.jpg
# augmented_data/no
# aug_41 no_0_4813.jpg
# augmented_data/no
# aug_23 no_0_7084.jpg
# augmented_data/no
# aug_no 10_0_714.jpg
# augmented_data/no
# aug_31 no_0_9850.jpg
# augmented_data/no
# aug_1 no._0_3940.jpg
# augmented_data/no
# aug_3 no_0_1002.jpg
# augmented_data/no
# aug_no 97_0_9152.jpg
# augmented_data/no
# aug_No17_0_1864.jpg
# augmented_data/no
# aug_no 89_0_5938.jpg
# augmented_data/no
# aug_no 3_0_865.jpg
# augmented_data/no
# aug_25 no_0_2280.jpg
# augmented_data/no
# aug_N2_0_6795.jpg
# augmented_data/no
# aug_26 no_0_3428.jpg
# augmented_data/no
# aug_22 no_0_3777.jpg
# augmented_data/no
# aug_30 no_0_4604.jpg
# augmented_data/no
# aug_14 no_0_5794.jpg
# augmented_data/no
# aug_no 97_0_3683.jpg
# augmented_data/no
# aug_29 no_0_4448.jpg
# augmented_data/no
# aug_N5_0_7162.jpg
# augmented_data/no
# aug_29 no_0_2763.jpg
# augmented_data/no
# aug_no 91._0_8735.jpg
# augmented_data/no
# aug_45 no_0_8813.jpg
# augmented_data/no
# aug_N22_0_6949.jpg
# augmented_data/no
# aug_no 90_0_3627.jpg
# augmented_data/no
# aug_no 91._0_7189.jpg
# augmented_data/no
# aug_18 no_0_2928.jpg
# augmented_data/no
# aug_No17_0_6677.jpg
# augmented_data/no
# aug_no 10_0_4051.jpg
# augmented_data/no
# aug_no 94_0_1844.jpg
# augmented_data/no
# aug_10 no_0_2978.jpg
# augmented_data/no
# aug_17 no_0_3243.jpg
# augmented_data/no
# aug_no 99_0_9360.jpg
# augmented_data/no
# aug_27 no_0_5320.jpg
# augmented_data/no
# aug_40 no_0_8607.jpg
# augmented_data/no
# aug_5 no_0_7646.jpg
# augmented_data/no
# aug_39 no_0_3860.jpg
# augmented_data/no
# aug_24 no_0_7532.jpg
# augmented_data/no
# aug_N6_0_3901.jpg
# augmented_data/no
# aug_no 92_0_4314.jpg
# augmented_data/no
# aug_No14_0_52.jpg
# augmented_data/no
# aug_18 no_0_2335.jpg
# augmented_data/no
# aug_N21_0_6414.jpg
# augmented_data/no
# aug_no 6_0_4362.jpg
# augmented_data/no
# aug_21 no_0_3375.jpg
# augmented_data/no
# aug_20 no_0_2065.jpg
# augmented_data/no
# aug_48 no._0_8028.jpg
# augmented_data/no
# aug_N15_0_6156.jpg
# augmented_data/no
# aug_N20_0_5993.jpg
# augmented_data/no
# aug_23 no_0_9109.jpg
# augmented_data/no
# aug_43 no_0_7094.jpg
# augmented_data/no
# aug_19 no_0_310.jpg
# augmented_data/no
# aug_40 no_0_2466.jpg
# augmented_data/no
# aug_No18_0_1966.jpg
# augmented_data/no
# aug_N11_0_7751.jpg
# augmented_data/no
# aug_7 no_0_9886.jpg
# augmented_data/no
# aug_No13_0_8751.jpg
# augmented_data/no
# aug_No22_0_5336.jpg
# augmented_data/no
# aug_14 no_0_4885.jpg
# augmented_data/no
# aug_30 no_0_7694.jpg
# augmented_data/no
# aug_3 no_0_1798.jpg
# augmented_data/no
# aug_34 no_0_9257.jpg
# augmented_data/no
# aug_7 no_0_6343.jpg
# augmented_data/no
# aug_no 7._0_2284.jpg
# augmented_data/no
# aug_N2_0_953.jpg
# augmented_data/no
# aug_47 no_0_2853.jpg
# augmented_data/no
# aug_38 no_0_4939.jpg
# augmented_data/no
# aug_no 9_0_197.jpg
# augmented_data/no
# aug_26 no_0_9106.jpg
# augmented_data/no
# aug_no 923_0_5086.jpg
# augmented_data/no
# aug_23 no_0_8834.jpg
# augmented_data/no
# aug_no 100_0_2181.jpg
# augmented_data/no
# aug_9 no_0_6126.jpg
# augmented_data/no
# aug_37 no_0_7242.jpg
# augmented_data/no
# aug_4 no_0_4544.jpg
# augmented_data/no
# aug_no 99_0_1449.jpg
# augmented_data/no
# aug_26 no_0_7466.jpg
# augmented_data/no
# aug_38 no_0_9993.jpg
# augmented_data/no
# aug_42 no_0_5934.jpg
# augmented_data/no
# aug_13 no_0_7231.jpg
# augmented_data/no
# aug_no 4_0_1721.jpg
# augmented_data/no
# aug_17 no_0_5023.jpg
# augmented_data/no
# aug_28 no_0_6093.jpg
# augmented_data/no
# aug_no 89_0_9127.jpg
# augmented_data/no
# aug_37 no_0_6410.jpg
# augmented_data/no
# aug_9 no_0_3314.jpg
# augmented_data/no
# aug_N1_0_6174.jpg
# augmented_data/no
# aug_N20_0_7820.jpg
# augmented_data/no
# aug_N21_0_4014.jpg
# augmented_data/no
# aug_23 no_0_4438.jpg
# augmented_data/no
# aug_31 no_0_4219.jpg
# augmented_data/no
# aug_43 no_0_9906.jpg
# augmented_data/no
# aug_3 no_0_2119.jpg
# augmented_data/no
# aug_19 no_0_6160.jpg
# augmented_data/no
# aug_27 no_0_9914.jpg
# augmented_data/no
# aug_19 no_0_8824.jpg
# augmented_data/no
# aug_No18_0_185.jpg
# augmented_data/no
# aug_N26_0_8881.jpg
# augmented_data/no
# aug_no 99_0_3474.jpg
# augmented_data/no
# aug_no 89_0_2472.jpg
# augmented_data/no
# aug_no 98_0_7508.jpg
# augmented_data/no
# aug_no 9_0_964.jpg
# augmented_data/no
# aug_41 no_0_3203.jpg
# augmented_data/no
# aug_no 10_0_458.jpg
# augmented_data/no
# aug_N19_0_3508.jpg
# augmented_data/no
# aug_No11_0_303.jpg
# augmented_data/no
# aug_No19_0_7239.jpg
# augmented_data/no
# aug_no_0_3626.jpg
# augmented_data/no
# aug_N22_0_2686.jpg
# augmented_data/no
# aug_20 no_0_8997.jpg
# augmented_data/no
# aug_31 no_0_5842.jpg
# augmented_data/no
# aug_N2_0_4594.jpg
# augmented_data/no
# aug_8 no_0_2612.jpg
# augmented_data/no
# aug_no 1_0_6305.jpg
# augmented_data/no
# aug_no 100_0_4053.jpg
# augmented_data/no
# aug_N1_0_1970.jpg
# augmented_data/no
# aug_No20_0_4729.jpg
# augmented_data/no
# aug_no 98_0_6212.jpg
# augmented_data/no
# aug_22 no_0_7067.jpg
# augmented_data/no
# aug_no 96_0_2327.jpg
# augmented_data/no
# aug_13 no_0_4072.jpg
# augmented_data/no
# aug_no 92_0_9596.jpg
# augmented_data/no
# aug_45 no_0_9713.jpg
# augmented_data/no
# aug_N11_0_8063.jpg
# augmented_data/no
# aug_18 no_0_8769.jpg
# augmented_data/no
# aug_no 89_0_5241.jpg
# augmented_data/no
# aug_43 no_0_1972.jpg
# augmented_data/no
# aug_N15_0_9466.jpg
# augmented_data/no
# aug_no 96_0_9064.jpg
# augmented_data/no
# aug_34 no_0_7727.jpg
# augmented_data/no
# aug_No11_0_6281.jpg
# augmented_data/no
# aug_1 no._0_6397.jpg
# augmented_data/no
# aug_no_0_1636.jpg
# augmented_data/no
# aug_no 2_0_5830.jpg
# augmented_data/no
# aug_11 no_0_4911.jpg
# augmented_data/no
# aug_50 no_0_583.jpg
# augmented_data/no
# aug_No20_0_8476.jpg
# augmented_data/no
# aug_46 no_0_3574.jpg
# augmented_data/no
# aug_6 no_0_819.jpg
# augmented_data/no
# aug_no 90_0_1778.jpg
# augmented_data/no
# aug_25 no_0_211.jpg
# augmented_data/no
# aug_no 6_0_8831.jpg
# augmented_data/no
# aug_8 no_0_8464.jpg
# augmented_data/no
# aug_no 98_0_7125.jpg
# augmented_data/no
# aug_N20_0_7762.jpg
# augmented_data/no
# aug_No11_0_8051.jpg
# augmented_data/no
# aug_N17_0_5149.jpg
# augmented_data/no
# aug_N16_0_1021.jpg
# augmented_data/no
# aug_no 10_0_2585.jpg
# augmented_data/no
# aug_43 no_0_340.jpg
# augmented_data/no
# aug_32 no_0_6142.jpg
# augmented_data/no
# aug_32 no_0_9271.jpg
# augmented_data/no
# aug_9 no_0_2782.jpg
# augmented_data/no
# aug_N17_0_6246.jpg
# augmented_data/no
# aug_no 923_0_8607.jpg
# augmented_data/no
# aug_no 90_0_6361.jpg
# augmented_data/no
# aug_2 no._0_7376.jpg
# augmented_data/no
# aug_no 94_0_7957.jpg
# augmented_data/no
# aug_26 no_0_379.jpg
# augmented_data/no
# aug_no 923_0_7050.jpg
# augmented_data/no
# aug_N19_0_9971.jpg
# augmented_data/no
# aug_no 9_0_9806.jpg
# augmented_data/no
# aug_12 no_0_8269.jpg
# augmented_data/no
# aug_No19_0_8647.jpg
# augmented_data/no
# aug_31 no_0_9060.jpg
# augmented_data/no
# aug_46 no_0_3172.jpg
# augmented_data/no
# aug_no 90_0_19.jpg
# augmented_data/no
# aug_no 91._0_8309.jpg
# augmented_data/no
# aug_No17_0_4886.jpg
# augmented_data/no
# aug_29 no_0_8855.jpg
# augmented_data/no
# aug_43 no_0_8410.jpg
# augmented_data/no
# aug_38 no_0_3329.jpg
# augmented_data/no
# aug_34 no_0_8826.jpg
# augmented_data/no
# aug_40 no_0_3150.jpg
# augmented_data/no
# aug_no_0_1378.jpg
# augmented_data/no
# aug_N15_0_8579.jpg
# augmented_data/no
# aug_22 no_0_8425.jpg
# augmented_data/no
# aug_no 4_0_4886.jpg
# augmented_data/no
# aug_no 5._0_2102.jpg
# augmented_data/no
# aug_43 no_0_4174.jpg
# augmented_data/no
# aug_N19_0_1268.jpg
# augmented_data/no
# aug_36 no_0_8151.jpg
# augmented_data/no
# aug_9 no_0_4079.jpg
# augmented_data/no
# aug_3 no_0_4426.jpg
# augmented_data/no
# aug_no 100_0_5824.jpg
# augmented_data/no
# aug_no 6_0_3556.jpg
# augmented_data/no
# aug_no 1_0_5418.jpg
# augmented_data/no
# aug_48 no._0_292.jpg
# augmented_data/no
# aug_36 no_0_5887.jpg
# augmented_data/no
# aug_N15_0_2727.jpg
# augmented_data/no
# aug_36 no_0_2124.jpg
# augmented_data/no
# aug_30 no_0_7863.jpg
# augmented_data/no
# aug_40 no_0_3145.jpg
# augmented_data/no
# aug_no 99_0_2344.jpg
# augmented_data/no
# aug_21 no_0_7262.jpg
# augmented_data/no
# aug_N3_0_8908.jpg
# augmented_data/no
# aug_34 no_0_1036.jpg
# augmented_data/no
# aug_no 3_0_2103.jpg
# augmented_data/no
# aug_17 no_0_740.jpg
# augmented_data/no
# aug_No22_0_1157.jpg
# augmented_data/no
# aug_19 no_0_5137.jpg
# augmented_data/no
# aug_14 no_0_6887.jpg
# augmented_data/no
# aug_N26_0_5141.jpg
# augmented_data/no
# aug_N6_0_482.jpg
# augmented_data/no
# aug_17 no_0_5810.jpg
# augmented_data/no
# aug_25 no_0_3207.jpg
# augmented_data/no
# aug_42 no_0_6817.jpg
# augmented_data/no
# aug_No11_0_9947.jpg
# augmented_data/no
# aug_2 no._0_5204.jpg
# augmented_data/no
# aug_35 no_0_618.jpg
# augmented_data/no
# aug_no 1_0_2571.jpg
# augmented_data/no
# aug_No17_0_716.jpg
# augmented_data/no
# Number of examples is:2065

# %%
def plot_sample_images(X, y, n=50):

    for label in [0,1]:
        # grab the first n images with the corresponding y values equal to label
        images = X[np.argwhere(y == label)]
        n_images = images[:n]

        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(20, 10))

        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])

            # remove ticks
            plt.tick_params(axis='both', which='both',
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)

            i += 1

        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle("Brain Tumor: {}".format(label_to_str(label)))
        plt.show()

plot_sample_images(X, y)

# %%
def split_data(X, y, test_size=0.2):

    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of development examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(y_train.shape))
print ("X_val (dev) shape: " + str(X_val.shape))
print ("Y_val (dev) shape: " + str(y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(y_test.shape))
# Out:
# number of training examples = 1445
# number of development examples = 310
# number of test examples = 310
# X_train shape: (1445, 240, 240, 3)
# Y_train shape: (1445, 1)
# X_val (dev) shape: (310, 240, 240, 3)
# Y_val (dev) shape: (310, 1)
# X_test shape: (310, 240, 240, 3)
# Y_test shape: (310, 1)

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{}:{}".format(h,m,round(s,1))

# %%
def compute_f1_score(y_true, prob):
    # convert the vector of probabilities to a target vector
    y_pred = np.where(prob > 0.5, 1, 0)
    score = f1_score(y_true, y_pred)

    return score

# %%
def build_model(input_shape):
    # Define the input placeholder as a tensor with shape input_shape. 
    X_input = Input(input_shape)
    X = Conv2D(64, (3, 3), strides = (1, 1), name = 'conv0')(X_input)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) # 

    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool0')(X) # 
    # X=Dropout(0.50)(X)


    X = Conv2D(128, (5, 5), strides=(2, 2), name='conv1')(X)
    X = BatchNormalization(axis=3, name='bn1')(X)
    X = Activation('relu')(X)  # shape=(?, 238, 238, 32)
    # MAXPOOL
    X = MaxPooling2D((4, 4), name='max_pool1')(X) # shape=(?, 14, 14, 32)
    X=Dropout(0.50)(X)

    # FLATTEN X 
    X = Flatten()(X) # shape=(?, 6272)
    # FULLYCONNECTED
    X = Dense(1, activation='sigmoid', name='fc')(X) # shape=(?, 1)


    model = Model(inputs = X_input, outputs = X, name='BrainDetectionModel')

    return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model = build_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "BrainDetectionModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  conv0 (Conv2D)              (None, 238, 238, 64)      1792
#
#  bn0 (BatchNormalization)    (None, 238, 238, 64)      256
#
#  activation (Activation)     (None, 238, 238, 64)      0
#
#  max_pool0 (MaxPooling2D)    (None, 119, 119, 64)      0
#
#  conv1 (Conv2D)              (None, 58, 58, 128)       204928
#
#  bn1 (BatchNormalization)    (None, 58, 58, 128)       512
#
#  activation_1 (Activation)   (None, 58, 58, 128)       0
#
#  max_pool1 (MaxPooling2D)    (None, 14, 14, 128)       0
#
#  dropout (Dropout)           (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc (Dense)                  (None, 1)                 25089
#
# =================================================================
# Total params: 232577 (908.50 KB)
# Trainable params: 232193 (907.00 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


import time

# tensorboard
log_file_name = 'brain_tumor_detection_cnn_{}'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(log_file_name))




# checkpoint
# unique file name that will include the epoch and the validation (development) accuracy
filepath="cnn-parameters-improvement-{epoch:02d}-{val_acc:.2f}"
# save the model with the best validation (development) accuracy till now
checkpoint = ModelCheckpoint("models/{}.keras".format(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max'))

#checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max'))

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.0001)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)
checkpoint = ModelCheckpoint('model_checkpoint.keras', monitor='val_loss', save_best_only=True)


# Start the timer
start_time = time.time()

# Train the model
history = model.fit(x=X_train, y=y_train, batch_size=32, epochs=30, 
                    validation_data=(X_val, y_val), 
                    callbacks=[reduce_lr, tensorboard, checkpoint])

# End the timer
end_time = time.time()
execution_time = end_time - start_time

# Print elapsed time
print("Elapsed time: {}".format(hms_string(execution_time)))
# Out:
# Epoch 1/30
# 46/46 [==============================] - 34s 726ms/step - loss: 1.3082 - accuracy: 0.6221 - val_loss: 0.7058 - val_accuracy: 0.5258 - lr: 0.0010
# Epoch 2/30
# 46/46 [==============================] - 34s 731ms/step - loss: 0.6068 - accuracy: 0.7453 - val_loss: 0.7655 - val_accuracy: 0.5097 - lr: 0.0010
# Epoch 3/30
# 46/46 [==============================] - 33s 719ms/step - loss: 0.5684 - accuracy: 0.7612 - val_loss: 1.1038 - val_accuracy: 0.5032 - lr: 0.0010
# Epoch 4/30
# 46/46 [==============================] - 33s 712ms/step - loss: 0.4447 - accuracy: 0.8138 - val_loss: 1.3631 - val_accuracy: 0.5032 - lr: 0.0010
# Epoch 5/30
# 46/46 [==============================] - 33s 726ms/step - loss: 0.5136 - accuracy: 0.8131 - val_loss: 0.5589 - val_accuracy: 0.6806 - lr: 0.0010
# Epoch 6/30
# 46/46 [==============================] - 33s 720ms/step - loss: 0.3580 - accuracy: 0.8581 - val_loss: 0.5742 - val_accuracy: 0.6323 - lr: 0.0010
# Epoch 7/30
# 46/46 [==============================] - 34s 730ms/step - loss: 0.3543 - accuracy: 0.8567 - val_loss: 0.5063 - val_accuracy: 0.7226 - lr: 0.0010
# Epoch 8/30
# 46/46 [==============================] - 33s 712ms/step - loss: 0.2683 - accuracy: 0.8983 - val_loss: 0.4528 - val_accuracy: 0.7484 - lr: 0.0010
# Epoch 9/30
# 46/46 [==============================] - 33s 716ms/step - loss: 0.4755 - accuracy: 0.8415 - val_loss: 0.4553 - val_accuracy: 0.7742 - lr: 0.0010
# Epoch 10/30
# 46/46 [==============================] - 33s 710ms/step - loss: 0.2827 - accuracy: 0.8927 - val_loss: 0.4900 - val_accuracy: 0.7710 - lr: 0.0010
- val_accuracy: 0.8323 - lr: 0.0010
# Epoch 28/30
# 46/46 [==============================] - 32s 701ms/step - loss: 0.0644 - accuracy: 0.9737 - val_loss: 0.5751 - val_accuracy: 0.8290 - lr: 2.0000e-04
# Epoch 29/30
# 46/46 [==============================] - 32s 701ms/step - loss: 0.0688 - accuracy: 0.9779 - val_loss: 0.2313 - val_accuracy: 0.9194 - lr: 2.0000e-04
# Epoch 30/30
# 46/46 [==============================] - 32s 704ms/step - loss: 0.0545 - accuracy: 0.9792 - val_loss: 0.2476 - val_accuracy: 0.8968 - lr: 2.0000e-04
# Elapsed time: 0:16:22.2

# %%
history = model.history.history

for key in history.keys():
    print(key)
# Out:
# loss
# accuracy
# val_loss
# val_accuracy
# lr

# %%
def plot_metrics(history):

    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']

    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()

    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()




plot_metrics(history)

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
loss, acc =model.evaluate(x=X_test, y=y_test)
# Out:
# 10/10 [==============================] - 2s 186ms/step - loss: 0.2797 - accuracy: 0.9097

# %%
print ("Test Loss = {}".format(loss))
print ("Test Accuracy = {}".format(acc))
# Out:
# Test Loss = 0.27967727184295654
# Test Accuracy = 0.9096774458885193

# %%
y_test_prob = model.predict(X_test)
# Out:
# 10/10 [==============================] - 2s 185ms/step

# %%
f1score = compute_f1_score(y_test, y_test_prob)
print(f"F1 score: {f1score}")
# Out:
# F1 score: 0.9217877094972067

# %%
y_val_prob = model.predict(X_val)
# Out:
# 10/10 [==============================] - 2s 187ms/step

# %%
f1score_val = compute_f1_score(y_val, y_val_prob)
print(f"F1 score: {f1score_val}")
# Out:
# F1 score: 0.9012345679012346

# %%
def data_percentage(y):

    m=len(y)
    n_positive = np.sum(y)
    n_negative = m - n_positive

    pos_prec = (n_positive* 100.0)/ m
    neg_prec = (n_negative* 100.0)/ m

    print("Number of examples:{}".format(m))
    print("Percentage of positive examples: {}%, number of pos examples: {}".format(pos_prec,n_positive))
    print("Percentage of negative examples: {}%, number of neg examples: {}".format(neg_prec,n_negative))

# %%
data_percentage(y)
# Out:
# Number of examples:2065
# Percentage of positive examples: 52.54237288135593%, number of pos examples: 1085
# Percentage of negative examples: 47.45762711864407%, number of neg examples: 980

# %%
print("Training Data:")
data_percentage(y_train)
print("Validation Data:")
data_percentage(y_val)
print("Testing Data:")
data_percentage(y_test)
# Out:
# Training Data:
# Number of examples:1445
# Percentage of positive examples: 52.04152249134948%, number of pos examples: 752
# Percentage of negative examples: 47.95847750865052%, number of neg examples: 693
# Validation Data:
# Number of examples:310
# Percentage of positive examples: 50.32258064516129%, number of pos examples: 156
# Percentage of negative examples: 49.67741935483871%, number of neg examples: 154
# Testing Data:
# Number of examples:310
# Percentage of positive examples: 57.096774193548384%, number of pos examples: 177
# Percentage of negative examples: 42.903225806451616%, number of neg examples: 133

# %%
#print (f"Test Loss = {loss}")
print (f"Test Accuracy = {acc}")
print(f"F1 score: {f1score_val}")
# Out:
# Test Accuracy = 0.9096774458885193
# F1 score: 0.9012345679012346
